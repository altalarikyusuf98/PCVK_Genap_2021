# %% [markdown]
# <a href="https://colab.research.google.com/github/altalarikyusuf98/PCVK_Genap_2021/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/lambo_car.jpeg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/lambo_car.jpeg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) # nilai 2 untuk menunjukan bahwa tiap titik dibuat 3 channel yang mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
img_width = img.shape[0]
img_length = img.shape[1]
print('======((img))======')
print('Width : ', img_width)
print('Length : ', img_length)
img5_width = img.shape[0]
img5_length = img.shape[1]
print('======((Img5))======')
print('Width : ', img_width)
print('Length : ', img_length)
# Out:
# ======((img))======
# Width :  415
# Length :  739
# ======((Img5))======
# Width :  415
# Length :  739

# %%
img_rg = img.copy()
img_rg[:,:,0] = 0
plt.imshow(img_rg)

# %%
img_gb = img.copy()
img_gb[:,:,2] = 0
plt.imshow(img_gb)

# %%
img_no3 = img[10:100,10:100]
plt.imshow(img_no3)

# %%
img_no4 = img.copy()
img_no4[:,:, 0] = 0
img_no4[:,:, 2] = 0
plt.imshow(img_no4[10:100,:])

# %%
img_source = cv.imread('/content/drive/MyDrive/🥵/IMG_7737.JPG')
img_no5 = cv.cvtColor(img_source, cv.COLOR_BGR2RGB)
cv.rectangle(img_no5, pt1=(500,100), pt2=(40,170), color=(255,255,0), thickness=10)
cv.rectangle(img_no5, pt1=(100,100), pt2=(510,150), color=(255,255,0),thickness=10)
cv.rectangle(img_no5, pt1=(150,500), pt2=(510,150), color=(255,255,0),thickness=10)
cv.rectangle(img_no5, pt1=(350,500), pt2=(510,150), color=(255,255,0),thickness=10)
cv.rectangle(img_no5, pt1=(100,500), pt2=(600,550), color=(255,255,0),thickness=10)
plt.imshow(img_no5)

# %%
img_source2 = img_no5
img_no6 = cv.flip(img_source2, 0)
plt.imshow(img_no6)

# %%
img_source3 = cv.imread('/content/drive/MyDrive/🥵/IMG_7682.jpg')
img_no7 = cv.cvtColor(img_source3, cv.COLOR_BGR2RGB)
cv.rectangle(img_no7, pt1=(700,3000), pt2=(1600,2000), color = (255,0,0), thickness = 10)
cv.circle(img_no7, center = (1200,2500), radius = 500, color = (0,255,255), thickness = 10)
plt.imshow(img_no7)

# %%
img_source4 = cv.imread('/content/drive/MyDrive/🥵/IMG_7682.jpg')
img_no8 = cv.cvtColor(img_source4, cv.COLOR_BGR2RGB)
img_no8[3300:, :1000,0] = 0
img_no8[3300:, :1000,1] = 0
plt.imshow(img_no8)

# %%
font_pict = cv.FONT_HERSHEY_TRIPLEX
img_source5 = cv.imread('/content/drive/MyDrive/🥵/IMG_7682.jpg')
img_no9 = cv.cvtColor(img_source5, cv.COLOR_BGR2RGB)
cv.putText(img_no9, text="ALTALARIK Y.E", org=(550,2000), fontFace=font_pict, fontScale=10, color = (0,255,255), thickness = 5, lineType = cv.LINE_AA)
plt.imshow(img_no9)
